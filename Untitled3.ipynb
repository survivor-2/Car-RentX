# %% [markdown]
# <a href="https://colab.research.google.com/github/survivor-2/Car-RentX/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class SimpleAgent:
  def __init__(self, name="Basic Agent"):
    self.name = name
    self.current_task = None
    self.completed_task = []
    self.knowledge_base = []

  def perceive(self, environment_state):
    print(f"{self.name} perceives: {environment_state}")

  def plan(self, goal):
    print(f"{self.name} is planning to achieve: {goal}")
    if "make coffee" in goal.lower():
      self.current_task = [
          "Get coffee beans",
          "Grind beans",
          "Boil water",
          "Brew coffee",
          "Pour into cup"
      ]
    elif "write a book" in goal.lower():
      self.current_task = [
          "Gather data", "Outline report",
          "Draft sections", "Review and edit",
          "Finalize report"
      ]
    else:
      self.current_task = [goal]
    print(f"{self.name} planned steps: {self.current_task}")

  def act(self):
    if not self.current_task:
      print(f"{self.name}: No current to act upon.")
      return "No action taken"

    action = self.current_task.pop(0)
    print(f"{self.name}: Performing action: {action}")
    import time
    time.sleep(0.5)
    self.completed_task.append(action)
    return f"Completed {action}"

  def reflect(self, outcome):
    print(f"{self.name} reflected on outcome: {outcome}")
    self.knowledge_base.append(outcome)
    if not self.current_task:
      print(f"{self.name}: All planned steps for the current goal are completed. Reflecting on overall success.")
    else:
      print(f"{self.name}: Still {len(self.current_task)} steps remaining. Counting....")

# %%
def perciceve(self,enviornment_state):
    print(f"{self.name}percieves:{enviornment_state}")

# %%
def plan(self,goal):
  print(f"{self.name}is planning to achieve:{goal}")
  if"make coffee" in goal.lower():
    self.current_task=[
        "Get coffee beans",
        "Grind beans",
        "Boil water",
        "Brew coffee",
        "Pour into cup"
    ]
  elif"write a book" in goal.lower():
      self.current_task=[
          "Gather data","Outline report",
          "Draft sections","Review and edit",
          "Finalize report"
      ]
  else:
        self.current_task = [goal]
        print(f"{self.name}planned steps:{self.current_task}")

# %%
def act(self):
  if not self.current_task:
    print(f"{self.name}:No current to act upon.")
    return
  if self.current_task:
    action = self.current_task.pop(0)
    print(f"{self.name}:Performing action:{action}")
    import time
    time.sleep(0.5)
    self.completed_task.append(action)
    return f"Completed{action}"
    return "No action taken"

# %%
def reflect(self,outcome):
  print(f"{self.name}reflected on outcome:{outcome}")
  self.knowledge_base.append(outcome)
  if not self.currernt_task:
    print(f"{self.name}:All planed steps for the current goal are completed.Refelecting on overall success.")
  else:
      print(f"{self.name}:still{len(self.current_task)}steps remaining. Counting....")

# %%
agent = SimpleAgent("coffee Maker Agent")
goal = "Make coffee"
agent.perceive("Kitchen is ready for coffee making.")
agent.plan(goal)
while agent.current_task:
  result = agent.act()
  agent.reflect(result)

print(f"\n{agent.name} has completed all tasks for goal:'{goal}'")
print(f"Final completed task: {agent.completed_task}")
print(f"Knowledge base: {agent.knowledge_base}")
# Out:
# coffee Maker Agent perceives: Kitchen is ready for coffee making.
# coffee Maker Agent is planning to achieve: Make coffee
# coffee Maker Agent planned steps: ['Get coffee beans', 'Grind beans', 'Boil water', 'Brew coffee', 'Pour into cup']
# coffee Maker Agent: Performing action: Get coffee beans
# coffee Maker Agent reflected on outcome: Completed Get coffee beans
# coffee Maker Agent: Still 4 steps remaining. Counting....
# coffee Maker Agent: Performing action: Grind beans
# coffee Maker Agent reflected on outcome: Completed Grind beans
# coffee Maker Agent: Still 3 steps remaining. Counting....
# coffee Maker Agent: Performing action: Boil water
# coffee Maker Agent reflected on outcome: Completed Boil water
# coffee Maker Agent: Still 2 steps remaining. Counting....
# coffee Maker Agent: Performing action: Brew coffee
# coffee Maker Agent reflected on outcome: Completed Brew coffee
# coffee Maker Agent: Still 1 steps remaining. Counting....
# ...

# %%
# to simulate a different task like 'write report':

agent_report = SimpleAgent("Report Writer Agent")
goal_report = "Write a book"

agent_report.perceive("Research materials are available.")
agent_report.plan(goal_report)

while agent_report.current_task:
  result_report = agent_report.act()
  agent_report.reflect(result_report)

print(f"\n{agent_report.name} has completed all tasks for goal: '{goal_report}'")
print(f"Final completed task: {agent_report.completed_task}")
print(f"Knowledge base: {agent_report.knowledge_base}")
# Out:
# Report Writer Agent perceives: Research materials are available.
# Report Writer Agent is planning to achieve: Write a book
# Report Writer Agent planned steps: ['Gather data', 'Outline report', 'Draft sections', 'Review and edit', 'Finalize report']
# Report Writer Agent: Performing action: Gather data
# Report Writer Agent reflected on outcome: Completed Gather data
# Report Writer Agent: Still 4 steps remaining. Counting....
# Report Writer Agent: Performing action: Outline report
# Report Writer Agent reflected on outcome: Completed Outline report
# Report Writer Agent: Still 3 steps remaining. Counting....
# Report Writer Agent: Performing action: Draft sections
# Report Writer Agent reflected on outcome: Completed Draft sections
# Report Writer Agent: Still 2 steps remaining. Counting....
# Report Writer Agent: Performing action: Review and edit
# Report Writer Agent reflected on outcome: Completed Review and edit
# Report Writer Agent: Still 1 steps remaining. Counting....
# ...

# %%
report_knowledge_series=
pd.series(agent)
# Out:
#   File "/tmp/ipykernel_3602/788264961.py", line 1
#     report_knowledge_series=
#                              ^
# SyntaxError: invalid syntax
